# %%
import sqlite3
import pandas as pd

# %%
import json

# %%
conn = sqlite3.connect('/content/nba_salary.sqlite') #utilizamos qlite3 y la funcion connect para establecer la coneccion a la db y no sabemos cuales son las tablas que se encuentran en la misma
cursor = conn.cursor() #cursor nos da un objeto que nos permite establecer la conexion

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';") #para ver la info utilizamos ese codigo de db, nos muestra las tablas que se encuentran en la db
print(cursor.fetchall())
# Out:
# [('NBA_season1718_salary',), ('Seasons_Stats',)]

# %%
query = 'SELECT * FROM NBA_season1718_salary'
df=pd.read_sql_query(query,conn) #cuando queremos leer una de las tablas podemos utilizar una funcion de pandas con dos argumentos

# %%
df #en el dataframe podemos obtener el contenido de la tabla NBA_season1718_salary
# Out:
#         X1          Player   Tm  season17_18
# 0      1.0   Stephen Curry  GSW   34682550.0
# 1      2.0    LeBron James  CLE   33285709.0
# 2      3.0    Paul Millsap  DEN   31269231.0
# 3      4.0  Gordon Hayward  BOS   29727900.0
# 4      5.0   Blake Griffin  DET   29512900.0
# ..     ...             ...  ...          ...
# 568  569.0      Quinn Cook  NOP      25000.0
# 569  570.0   Chris Johnson  HOU      25000.0
# 570  571.0      Beno Udrih  DET      25000.0
# 571  572.0   Joel Bolomboy  MIL      22248.0
# 572  573.0    Jarell Eddie  CHI      17224.0
#
# [573 rows x 4 columns]

# %%
query = 'SELECT * FROM Seasons_Stats'
df=pd.read_sql_query(query,conn)

# %%
df
# Out:
#             X1    Year             Player  Pos   Age   Tm     G   GS      MP  \
# 0          0.0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0  NaN     NaN
# 1          1.0  1950.0       Cliff Barker   SG  29.0  INO  49.0  NaN     NaN
# 2          2.0  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0  NaN     NaN
# 3          3.0  1950.0         Ed Bartels    F  24.0  TOT  15.0  NaN     NaN
# 4          4.0  1950.0         Ed Bartels    F  24.0  DNN  13.0  NaN     NaN
# ...        ...     ...                ...  ...   ...  ...   ...  ...     ...
# 24686  24686.0  2017.0        Cody Zeller   PF  24.0  CHO  62.0  NaN  1725.0
# 24687  24687.0  2017.0       Tyler Zeller    C  27.0  BOS  51.0  NaN   525.0
# 24688  24688.0  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0  0.0   108.0
# 24689  24689.0  2017.0        Paul Zipser   SF  22.0  CHI  44.0  NaN   843.0
# 24690  24690.0  2017.0        Ivica Zubac    C  19.0  LAL  38.0  NaN   609.0
#
# ...

# %%
f=open("/content/ejemplo_1.json")
data = json.load(f)
data
# Out:
# {'Calories': {'0': 409, '1': 479, '2': 340, '3': 282, '4': 406, '5': 300},
#  'Duration': {'0': 60, '1': 60, '2': 60, '3': 45, '4': 45, '5': 60},
#  'Maxpulse': {'0': 130, '1': 145, '2': 135, '3': 175, '4': 148, '5': 127},
#  'Pulse': {'0': 110, '1': 117, '2': 103, '3': 109, '4': 117, '5': 102}}

# %%
with open("/content/ejemplo_1.json") as c:
  data2 = json.load(c)

# %%
data2
# Out:
# {'Calories': {'0': 409, '1': 479, '2': 340, '3': 282, '4': 406, '5': 300},
#  'Duration': {'0': 60, '1': 60, '2': 60, '3': 45, '4': 45, '5': 60},
#  'Maxpulse': {'0': 130, '1': 145, '2': 135, '3': 175, '4': 148, '5': 127},
#  'Pulse': {'0': 110, '1': 117, '2': 103, '3': 109, '4': 117, '5': 102}}
